# %% [markdown]
# Import Dependencies

# %%
# import libraries

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# Data collection

# %%
# loading dataset
diabetes_df = pd.read_csv('datasets/diabetes.csv')

diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Pre-processing

# %%
# checking shape

diabetes_df.shape
# Out:
# (768, 9)

# %%
# check for any null values

diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# Analysing the distribution of target

diabetes_df.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# Handling imbalanced dataset

# %%
# Bifurcating data based on class

non_diabetic = diabetes_df[diabetes_df.Outcome == 0]
diabetic = diabetes_df[diabetes_df.Outcome == 1]

print(non_diabetic.shape)
print(diabetic.shape)
# Out:
# (500, 9)
# (268, 9)

# %%
# Building dataset with similar distribution

non_diabetic_sampled = non_diabetic.sample(n = 268)

diabetes_sampled_df = pd.concat([diabetic, non_diabetic_sampled], axis = 0)

# %%
# verifying distribution

diabetes_sampled_df.Outcome.value_counts()
# Out:
# 1    268
# 0    268
# Name: Outcome, dtype: int64

# %% [markdown]
# Separating features and target

# %%
X =diabetes_sampled_df.drop(columns='Outcome', axis = 1)
Y = diabetes_sampled_df['Outcome']

print(X.shape)
print(Y.shape)
# Out:
# (536, 8)
# (536,)

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 2            8      183             64              0        0  23.3
# 4            0      137             40             35      168  43.1
# 6            3       78             50             32       88  31.0
# 8            2      197             70             45      543  30.5
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 2                     0.672   32
# 4                     2.288   33
# 6                     0.248   26
# 8                     0.158   53

# %%
Y.head()
# Out:
# 0    1
# 2    1
# 4    1
# 6    1
# 8    1
# Name: Outcome, dtype: int64

# %% [markdown]
# Data Standardization

# %%
# checking the standard deviation

X.std()
# Out:
# Pregnancies                   3.563081
# Glucose                      33.321772
# BloodPressure                19.654300
# SkinThickness                16.665407
# Insulin                     123.896826
# BMI                           7.803055
# DiabetesPedigreeFunction      0.340816
# Age                          11.813400
# dtype: float64

# %%
# standardizing the data

scale = StandardScaler()

# %%
scale.fit(X)
# Out:
# StandardScaler()

# %%
X_standardized = scale.transform(X)

# %%
X_standardized
# Out:
# array([[ 0.52567333,  0.67900332,  0.11411064, ...,  0.08234945,
#          0.40885569,  1.33242219],
#        [ 1.08750963,  1.73034883, -0.2933052 , ..., -1.23887937,
#          0.54101505, -0.19269458],
#        [-1.15983557,  0.34858044, -1.51555273, ...,  1.30095855,
#          5.28700451, -0.10796587],
#        ...,
#        [-1.15983557,  0.1082729 ,  0.52152648, ..., -0.22550969,
#          0.63205817, -0.44688071],
#        [-0.87891742, -1.06322639, -0.39515916, ..., -0.73860826,
#          0.27082258, -0.87052426],
#        [-0.59799927,  0.61892643,  0.31781856, ...,  0.6724128 ,
#         -0.46633296, -0.44688071]])

# %%
# checking the standard deviation

X_standardized.std()
# Out:
# 1.0

# %% [markdown]
# Splitting the data into testing and training

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_standardized, Y, test_size= 0.2, random_state = 2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (536, 8) (428, 8) (108, 8)
